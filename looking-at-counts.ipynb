# %%
import matplotlib.pyplot as plt
import json

# %%
with open('counts.json', 'r') as fd:
    counts = json.loads(fd.read())

# %%
plt.hist(list(counts.values()), bins = 100, log=True)
plt.title("Frequency (y) of biocontainers executables by count (x)")
plt.show()
